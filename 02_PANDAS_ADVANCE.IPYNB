# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('Online Retail Data Set.xlsx')

# %%
data.head(2)
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[us]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), object(3), str(1)
# memory usage: 33.1+ MB

# %%
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# data[data.StockCode == '85123A']

# %%
# data filtering
data[~data.Description.isnull()].shape
# Out:
# (540455, 8)

# %%
condition_1 = data.Description.isnull()
condition_2 = data.StockCode == '85123A'
cond

data[condition_1 | condition_2]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 0         536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 49        536373    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 66        536375    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 220       536390    85123A  WHITE HANGING HEART T-LIGHT HOLDER        64
# 262       536394    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
# ...          ...       ...                                 ...       ...
# 539342    581439    85123A  CREAM HANGING HEART T-LIGHT HOLDER         1
# 539979    581452    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
# 540217    581472    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 540837    581492    85123A  CREAM HANGING HEART T-LIGHT HOLDER         3
# 541639    581538    85123A  CREAM HANGING HEART T-LIGHT HOLDER         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='str')

# %%
data.Description.value_counts()
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2369
# REGENCY CAKESTAND 3 TIER              2200
# JUMBO BAG RED RETROSPOT               2159
# PARTY BUNTING                         1727
# LUNCH BAG RED RETROSPOT               1638
#                                       ...
# LETTER "U" BLING KEY RING                1
# wet                                      1
# wet boxes                                1
# ????damages????                          1
# lost                                     1
# Name: count, Length: 4223, dtype: int64

# %%
data['total_price'] = data['Quantity'] * data['UnitPrice']
data.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  total_price
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34

# %%
# 1. avg sales
data.groupby('Country')['total_price'].mean()

# 2. total sales
data.groupby('Country')['total_price'].sum()
# 3. max sales
data.groupby('Country')['total_price'].max()
# Out:
# Country
# Australia                 1718.40
# Austria                    360.00
# Bahrain                    205.74
# Belgium                    165.00
# Brazil                     175.20
# Canada                     550.94
# Channel Islands            408.00
# Cyprus                     320.69
# Czech Republic              70.80
# Denmark                    428.40
# EIRE                      2365.20
# European Community          60.00
# Finland                    551.20
# France                    4161.06
# Germany                    876.00
# Greece                     175.20
# Hong Kong                 2653.95
# Iceland                    249.60
# Israel                     350.40
# Italy                      300.00
# Japan                     3794.40
# Lebanon                    153.00
# Lithuania                  122.40
# Malta                      455.00
# Netherlands               4992.00
# Norway                     700.00
# Poland                     120.00
# ...

# %%
result_df =data.groupby('Country').agg({
    'total_price': ['mean', 'sum', 'max'],
    'Description': ['count']
})
result_df.head()
# Out:
#           total_price                     Description
#                  mean        sum      max       count
# Country
# Australia  108.877895  137077.27  1718.40        1259
# Austria     25.322494   10154.32   360.00         401
# Bahrain     28.863158     548.40   205.74          19
# Belgium     19.773301   40910.96   165.00        2069
# Brazil      35.737500    1143.60   175.20          32

# %%
data.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  total_price
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34

# %%
data.rename(columns={'Description': 'Product_Description'}, inplace=True)

# %%
def data_checks(df):
    checks ={
        'size_of_data': df.shape[0],
        'num_of_columns': df.shape[1],
        'missing_values': df.isnull().sum().sum(),
        'pct_missing': round(df.isnull().sum().sum() / (df.shape[0] * df.shape[1]) * 100,2)
    }
    return checks

data_checks(data)
# Out:
# {'size_of_data': 541909,
#  'num_of_columns': 9,
#  'missing_values': np.int64(136534),
#  'pct_missing': np.float64(2.8)}

# %%
data.groupby(['Country', 'Product_Description']).agg({
    'total_price': ['mean', 'sum', 'max'],
    'Product_Description': ['count']
})
# Out:
#                                           total_price                \
#                                                  mean    sum    max
# Country     Product_Description
# Australia    DOLLY GIRL BEAKER                  216.0  216.0  216.0
#              I LOVE LONDON MINI BACKPACK         16.6   16.6   16.6
#             10 COLOUR SPACEBOY PEN               40.8   40.8   40.8
#             12 PENCIL SMALL TUBE WOODLAND       211.2  211.2  211.2
#             12 PENCILS TALL TUBE POSY            39.9   79.8   69.6
# ...                                               ...    ...    ...
# Unspecified WRAP POPPIES  DESIGN                 10.5   10.5   10.5
#             WRAP SUKI AND FRIENDS                10.5   10.5   10.5
#             WRAP VINTAGE PETALS  DESIGN          10.5   10.5   10.5
#             WRAP WEDDING DAY                     10.5   10.5   10.5
#             ZINC METAL HEART DECORATION           2.5    2.5    2.5
#
# ...

# %%
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Product_Description', 'Quantity',
#        'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country', 'total_price'],
#       dtype='str')

# %%
data[['StockCode', 'Product_Description', 'Quantity']]
# Out:
#        StockCode                  Product_Description  Quantity
# 0         85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          71053                  WHITE METAL LANTERN         6
# 2         84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...                                  ...       ...
# 541904     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# [541909 rows x 3 columns]

# %%
def tagg_to_total_sales(sales):
    if sales > 100:
        return "High"
    elif sales > 50:
        return "Medium"
    else:
        return "Low"
    

data['sales_tag'] = data['total_price'].apply(tagg_to_total_sales)

# %%
data.sales_tag.value_counts()
# Out:
# sales_tag
# Low       510819
# Medium     17536
# High       13554
# Name: count, dtype: int64

# %%
data.head(5)
# Out:
#   InvoiceNo StockCode                  Product_Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  total_price  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom        22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
#
#   sales_tag
# 0       Low
# 1       Low
# 2       Low
# 3       Low
# 4       Low

# %%
# loc vs iloc?
# .loc is label-based( means col labels), while .iloc is position-based
data.loc[data['Country'] == 'United Kingdom', 'Product_Description']

# vs#

data.iloc[0:10, 2]
# Out:
# 0     WHITE HANGING HEART T-LIGHT HOLDER
# 1                    WHITE METAL LANTERN
# 2         CREAM CUPID HEARTS COAT HANGER
# 3    KNITTED UNION FLAG HOT WATER BOTTLE
# 4         RED WOOLLY HOTTIE WHITE HEART.
# 5           SET 7 BABUSHKA NESTING BOXES
# 6      GLASS STAR FROSTED T-LIGHT HOLDER
# 7                 HAND WARMER UNION JACK
# 8              HAND WARMER RED POLKA DOT
# 9          ASSORTED COLOUR BIRD ORNAMENT
# Name: Product_Description, dtype: object

# %%
#https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf
#https://www.kaggle.com/datasets/lakshmi25npathi/online-retail-dataset/data

# %%
data_1 = {
    'product_id':[1,2,3,4,5],
    'product':['A','B','C',"D","E"],
    'PRICE': [200,300,400,500,250]
}

product_df = pd.DataFrame(data_1)
product_df.head(2)
# Out:
#    product_id product  PRICE
# 0           1       A    200
# 1           2       B    300

# %%
data_2 = {
    'id':[1,2,1,1,5],
    'store': ['A',"B","C","D","A"]
}

sales_df = pd.DataFrame(data_2)

# %%
sales_df.head()
# Out:
#    id store
# 0   1     A
# 1   2     B
# 2   1     C
# 3   1     D
# 4   5     A

# %%
df4.join(df1,on='id',how=)

# %%
final_data = pd.merge(sales_df,product_df,how='left',left_on='',right_on='')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/fq/kr6gv5l17pd4j572n0_n3f2c0000gn/T/ipykernel_3434/2182112996.py in ?()
# ----> 1 final_data = pd.merge(sales_df,product_df,how='left',on='id')
#
# ~/Documents/02_Freelancing/AI_ML_Sathish/test-env/lib/python3.13/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     381             indicator=indicator,
#     382             validate=validate,
#     383         )
#     384     else:
# --> 385         op = _MergeOperation(
#     386             left_df,
#     387             right_df,
#     388             how=how,
#
# ...

# %%
final_data

# %%
df4 = pd.DataFrame(
    {
        "B": ["B2", "B3", "B6", "B7"],
        "D": ["D2", "D3", "D6", "D7"],
        "F": ["F2", "F3", "F6", "F7"],
    },
    # index=[2, 3, 6, 7],
)

df1 = pd.DataFrame(
    {
        "age": ["A0", "A1", "A2", "A3"],
        "salary": ["B0", "B1", "B2", "B3"],
        "gender": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    # index=[0, 1, 2, 3],
)
df4.head()
# Out:
#     B   D   F
# 0  B2  D2  F2
# 1  B3  D3  F3
# 2  B6  D6  F6
# 3  B7  D7  F7

# %%
df1.head()
# Out:
#   age salary gender   D
# 0  A0     B0     C0  D0
# 1  A1     B1     C1  D1
# 2  A2     B2     C2  D2
# 3  A3     B3     C3  D3

# %%
final_data = pd.concat([df1,df4],ignore_index=True)

# %%
final_data.head(10)
# Out:
#    age salary gender   D    B    F
# 0   A0     B0     C0  D0  NaN  NaN
# 1   A1     B1     C1  D1  NaN  NaN
# 2   A2     B2     C2  D2  NaN  NaN
# 3   A3     B3     C3  D3  NaN  NaN
# 4  NaN    NaN    NaN  D2   B2   F2
# 5  NaN    NaN    NaN  D3   B3   F3
# 6  NaN    NaN    NaN  D6   B6   F6
# 7  NaN    NaN    NaN  D7   B7   F7

# %%
final_data.reset_index()
# Out:
#    index  age salary gender   D    B    F
# 0      0   A0     B0     C0  D0  NaN  NaN
# 1      1   A1     B1     C1  D1  NaN  NaN
# 2      2   A2     B2     C2  D2  NaN  NaN
# 3      3   A3     B3     C3  D3  NaN  NaN
# 4      0  NaN    NaN    NaN  D2   B2   F2
# 5      1  NaN    NaN    NaN  D3   B3   F3
# 6      2  NaN    NaN    NaN  D6   B6   F6
# 7      3  NaN    NaN    NaN  D7   B7   F7

# %%
s1 = pd.Series(["X0", "X1", "X2", "X3"], name="X")
s1
# Out:
# 0    X0
# 1    X1
# 2    X2
# 3    X3
# Name: X, dtype: str

# %%
df1
# Out:
#   age salary gender   D
# 0  A0     B0     C0  D0
# 1  A1     B1     C1  D1
# 2  A2     B2     C2  D2
# 3  A3     B3     C3  D3

# %%
result = pd.concat([df1, s1],keys=['X',"Y"])
result
# Out:
#      age salary gender    D    X
# X 0   A0     B0     C0   D0  NaN
#   1   A1     B1     C1   D1  NaN
#   2   A2     B2     C2   D2  NaN
#   3   A3     B3     C3   D3  NaN
# Y 0  NaN    NaN    NaN  NaN   X0
#   1  NaN    NaN    NaN  NaN   X1
#   2  NaN    NaN    NaN  NaN   X2
#   3  NaN    NaN    NaN  NaN   X3

# %%
result.loc['Y']
# Out:
#    age salary gender    D   X
# 0  NaN    NaN    NaN  NaN  X0
# 1  NaN    NaN    NaN  NaN  X1
# 2  NaN    NaN    NaN  NaN  X2
# 3  NaN    NaN    NaN  NaN  X3
