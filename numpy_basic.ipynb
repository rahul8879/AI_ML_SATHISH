# %%
import plotly.express as px

df = px.data.iris()

# fig = px.scatter_3d(df, x = 'sepal_width', 
#                     y = 'sepal_length', 
#                     z = 'petal_width',
#                     color = 'species')

# fig.show()

# %%
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1

# %%
fig = px.scatter_3d(df, x = 'sepal_width', 
                    y = 'sepal_length', 
                    z = 'petal_width',
                    color = 'species')

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       1 fig = px.scatter_3d(df, x = 'sepal_width',
#       2                     y = 'sepal_length',
#       3                     z = 'petal_width',
#       4                     color = 'species')
# ----> 6 fig.show()
#
# File ~/Documents/02_Freelancing/AI_ML_Sathish/test-env/lib/python3.13/site-packages/plotly/basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File ~/Documents/02_Freelancing/AI_ML_Sathish/test-env/lib/python3.13/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
# ...
