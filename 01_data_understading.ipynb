# %%
import pandas as pd

# %%
data = {

'cid' : [1,2,3,4,5,6],
'income': [21,2,22,24,25,27],
'Status':['Yes','NO','YES','YES','YES',"YES"]

}

data_df = pd.DataFrame(data)

# %%
data_df.to_csv('test.csv',index=False)

# %%
data = pd.read_csv('test.csv')

# %%
data.head()
# Out:
#    cid  income Status
# 0    1      21    Yes
# 1    2       2     NO
# 2    3      22    YES
# 3    4      24    YES
# 4    5      25    YES

# %%
type(data)
# Out:
# pandas.DataFrame

# %%
type(data['cid'])
# Out:
# pandas.Series

# %%
data.describe(include="all")
# Out:
#              cid     income Status
# count   6.000000   6.000000      6
# unique       NaN        NaN      3
# top          NaN        NaN    YES
# freq         NaN        NaN      4
# mean    3.500000  20.166667    NaN
# std     1.870829   9.152413    NaN
# min     1.000000   2.000000    NaN
# 25%     2.250000  21.250000    NaN
# 50%     3.500000  23.000000    NaN
# 75%     4.750000  24.750000    NaN
# max     6.000000  27.000000    NaN

# %%
data.income
# Out:
# 0    21
# 1     2
# 2    22
# 3    24
# 4    25
# 5    27
# Name: income, dtype: int64

# %%
data['Monthly sales'] = [22,22,24,23,23,21]

# %%
data['Monthly sales']
# Out:
# 0    22
# 1    22
# 2    24
# 3    23
# 4    23
# 5    21
# Name: Monthly sales, dtype: int64

# %%
data.income.plot()
# Out:
# <Axes: >
